# %%
import pandas as pd

res_princ_2016 = pd.read_csv("C:/Users/gromm/Downloads/Proprio_VS_Locataires_ResidencesPrincipales2016.csv")

# %%
display(res_princ_2016)
# Out:
#    Résidences principales selon la taille des ménages et le statut d'occupation en 2016  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                      Au 1er janvier
# 3                                        Propriétaire
# 4                Locataire d'un logement vide non HLM
# 5                    Locataire d'un logement vide HLM
# 6                 Locataire d'un logement loué meublé
# 7                                   Logé gratuitement
# 8                                               Total
# 9                        Champ : France hors Mayotte.
# 10   Source : Insee, RP 2016 exploitation principale.
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5       Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN        NaN              NaN
# 1         NaN        NaN        NaN        NaN        NaN              NaN
# ...

# %%
res_princ_2016 = res_princ_2016.drop(res_princ_2016.index[-2:])

# %%
res_princ_2016.columns = ["residences_principales", "1 pers.", "2. pers.", "3 pers.", "4 pers.", "5 pers.",	"6 pers. ou plus", "Total"]
res_princ_2016 = res_princ_2016.drop(res_princ_2016.index[:3])
display(res_princ_2016)
# Out:
#                  residences_principales 1 pers. 2. pers. 3 pers. 4 pers.  \
# 3                          Propriétaire   4,736    6,374   2,433   2,320
# 4  Locataire d'un logement vide non HLM   3,122    1,809     841     533
# 5      Locataire d'un logement vide HLM   1,689    1,066     655     475
# 6   Locataire d'un logement loué meublé     593      138      45      26
# 7                     Logé gratuitement     315      168      89      69
# 8                                 Total  10,454    9,555   4,064   3,422
#
#   5 pers. 6 pers. ou plus   Total
# 3     748             220  16,830
# 4     205              97   6,607
# 5     267             158   4,311
# 6      11               6     819
# 7      21               9     670
# 8   1,253             490  29,237

# %%
res_princ_2016.to_csv("ResidencePrincipales2016.csv", index = False)
