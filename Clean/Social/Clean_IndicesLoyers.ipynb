# %%
import pandas as pd

indice_loyer = pd.read_csv("C:/Users/gromm/Downloads/Proprio_VS_Locataires_IndiceLoyersAnnuel.csv")
display(indice_loyer)

# %%
# Renamed columns
indice_loyer.columns = ["evolution_annuelle_indice_loyers", "indice_general", "indice_secteur_libre", "indice_secteur_social"]

# Removed useless rows
indice_loyer = indice_loyer.drop(indice_loyer.index[:3])
indice_loyer = indice_loyer.drop(indice_loyer.index[-4:])

display(indice_loyer)
# Out:
#     evolution_annuelle_indice_loyers indice_general indice_secteur_libre  \
# 3                             Jan-88            6.0                  6.5
# 4                             Apr-88            6.0                  6.5
# 5                             Jul-88            5.9                  6.1
# 6                             Oct-88            5.4                  5.9
# 7                             Jan-89            5.6                  6.4
# ..                               ...            ...                  ...
# 126                           Oct-18           -0.7                  0.6
# 127                           Jan-19           -0.3                  0.7
# 128                           Apr-19           -0.3                  0.9
# 129                           Jul-19            1.1                  0.9
# 130                           Oct-19            1.1                  0.9
#
#     indice_secteur_social
# 3                     5.0
# 4                     5.2
# ...

# %%
# Check for NaN values

indice_loyer.isna().sum()
# Out:
# evolution_annuelle_indice_loyers    0
# indice_general                      0
# indice_secteur_libre                0
# indice_secteur_social               0
# dtype: int64

# %%
# Export

indice_loyer.to_csv("IndiceLoyers.csv", index = False)
