# %%
import pandas as pd

# %% [markdown]
# importation du fichier des logements vacants ==>

# %%
df = pd.read_excel("/data/Projet_reconversion/Projet et cours Data Analyst/Cours Le Wagon/projet_crise_logement/Donnees a nettoyer/Immobilier/Nature_des_logements/LogementsVacants_France.xlsx", sheet_name="COM")
df.head(5)
# Out:
#   CODGEO_25                LIBGEO_25 pp_vacant_25 pp_vacant_plus_2ans_25  \
# 0     01001  L'Abergement-Clémenciat            s                      s
# 1     01002    L'Abergement-de-Varey            s                      s
# 2     01004        Ambérieu-en-Bugey          374                    207
# 3     01005      Ambérieux-en-Dombes           28                     13
# 4     01006                  Ambléon            s                      s
#
#   pp_total_24 pp_vacant_24 pp_vacant_plus_2ans_24 pp_total_23 pp_vacant_23  \
# 0         358           15                      s         355           15
# 1         180           11                      s         180            s
# 2        5949          628                    200        5918          626
# 3         809           61                      s         795           39
# 4           s            s                      s           s            s
#
# ...

# %% [markdown]
# Filtre par "Métropole Européenne de Lille" pour ne garder que la métropole lilloise

# %%
df_mel = df[df["LIB_EPCI_25"]=="Métropole Européenne de Lille"]
# Out:
#       CODGEO_25            LIBGEO_25 pp_vacant_25 pp_vacant_plus_2ans_25  \
# 21760     59005  Allennes-les-Marais           44                     20
# 21764     59009    Villeneuve-d'Ascq          743                    289
# 21766     59011            Annœullin          139                     68
# 21768     59013             Anstaing           21                      s
# 21772     59017          Armentières          845                    407
# ...         ...                  ...          ...                    ...
# 22385     59653               Wavrin           87                     41
# 22388     59656          Wervicq-Sud           54                     30
# 22390     59658               Wicres            s                      s
# 22392     59660              Willems           37                     11
# 22402     59670                  Don           13                      s
#
#       pp_total_24 pp_vacant_24 pp_vacant_plus_2ans_24 pp_total_23  \
# ...

# %% [markdown]
# Export en fichier csv exploitable

# %%
df.to_csv("logement_vacants_MEL.csv", index=False)
