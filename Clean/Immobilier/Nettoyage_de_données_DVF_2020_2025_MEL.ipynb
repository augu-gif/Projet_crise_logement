# %% [markdown]
# <a href="https://colab.research.google.com/github/augu-gif/Projet_crise_logement/blob/main/nettoyage_de_donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# importation des données par années

# %% [markdown]
# df_2022 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2022.csv", sep="|",low_memory=False)
# df_2023 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2023.csv", sep="|",low_memory=False)
# df_2024 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2024.csv", sep="|",low_memory=False)
# df_2025 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2025-S1.csv", sep="|",low_memory=False)

# %%
df_2020 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2020-S2.csv", sep="|",low_memory=False)

# %%
df_2021 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2021.csv", sep="|",low_memory=False)

# %%
df_2022 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2022.csv", sep="|",low_memory=False)

# %%
df_2023 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2023.csv", sep="|",low_memory=False)

# %%
df_2024 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2024.csv", sep="|",low_memory=False)

# %%
df_2025 = pd.read_csv("drive/MyDrive/Ventes_immobilière_2020_2025/ValeursFoncieres-2025-S1.csv", sep="|",low_memory=False)

# %%
df_2021.columns
# Out:
# Index(['Identifiant de document', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %% [markdown]
# visualisation du nom des colonnes

# %%
cols = [
    "Date mutation",
    "Valeur fonciere",
    "Type local",
    "Surface reelle bati",
    "Nombre pieces principales",
    "Commune",
    "Code departement",
    "Code postal",
    "Surface terrain"
]

df_2020 = df_2020[cols]

# %% [markdown]
# sélection des colonnes exploitable

# %%
df_2021 = df_2021[cols]

# %%
df_2022 = df_2022[cols]

# %%
df_2023 = df_2023[cols]

# %%
df_2024 = df_2024[cols]

# %%
df_2025 = df_2025[cols]

# %% [markdown]
# affinache des données pour concatenation

# %%
df_concat = pd.concat([df_2020, df_2021, df_2022, df_2023, df_2024, df_2025],
    axis=0,
    join="inner",
    ignore_index=True
)

# %% [markdown]
# filtre par code postal de la mel

# %%
df_mel = pd.read_csv("drive/MyDrive/Projet_crise_logement/Données_nettoyées/villes_mel.csv")

# %%
code_departement = df_mel["Code departement"].tolist()

# %%
df = df_concat[df_concat["Code departement"].isin(code_departement)]

# %%
df.shape
# Out:
# (204321, 9)

# %%
df.to_csv("DVF_MEL.csv", index=False, sep="|")

# %% [markdown]
# exctraction en csv
